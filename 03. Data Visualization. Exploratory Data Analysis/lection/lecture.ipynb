# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn
import bokeh
# vega altair

# %% [markdown]
# # there is no shuch dataset

# %%
whr_2017 = pd.read_csv("data/2017.csv")
whr_2018 = pd.read_csv("data/2018.csv")
whr_2019 = pd.read_csv("data/2019.csv")

# %%
# plt.xkcd()
# plt.style.use("bmh")

# %%
whr_2018
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# 1             1.582                    0.861                         0.686
# 2             1.590                    0.868                         0.683
# 3             1.644                    0.914                         0.677
# 4             1.549                    0.927                         0.660
# ..              ...                      ...                           ...
# 151           1.073                    0.343                         0.244
# 152           0.991                    0.381                         0.481
# 153           0.608                    0.177                         0.112
# 154           0.000                    0.010                         0.305
# 155           0.627                    0.145                         0.065
#
#      Generosity  Perceptions of corruption
# 0         0.202                      0.393
# 1         0.286                      0.340
# 2         0.284                      0.408
# 3         0.353                      0.138
# 4         0.256                      0.357
# ..          ...                        ...
# 151       0.083                      0.064
# 152       0.270                      0.097
# 153       0.224                      0.106
# 154       0.218                      0.038
# 155       0.149                      0.076
#
# [156 rows x 9 columns]

# %%
whr_2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# 1             1.573                    0.996                         0.592
# 2             1.582                    1.028                         0.603
# 3             1.624                    1.026                         0.591
# 4             1.522                    0.999                         0.557
# ..              ...                      ...                           ...
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 0         0.153                      0.393
# 1         0.252                      0.410
# 2         0.271                      0.341
# 3         0.354                      0.118
# 4         0.322                      0.298
# ..          ...                        ...
# 151       0.217                      0.411
# 152       0.276                      0.147
# 153       0.158                      0.025
# 154       0.235                      0.035
# 155       0.202                      0.091
#
# [156 rows x 9 columns]

# %%
whr_2018.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
whr_2018.describe().T
# Out:
#                               count       mean        std    min       25%  \
# Overall rank                  156.0  78.500000  45.177428  1.000  39.75000
# Score                         156.0   5.375917   1.119506  2.905   4.45375
# GDP per capita                156.0   0.891449   0.391921  0.000   0.61625
# Social support                156.0   1.213237   0.302372  0.000   1.06675
# Healthy life expectancy       156.0   0.597346   0.247579  0.000   0.42225
# Freedom to make life choices  156.0   0.454506   0.162424  0.000   0.35600
# Generosity                    156.0   0.181006   0.098471  0.000   0.10950
# Perceptions of corruption     155.0   0.112000   0.096492  0.000   0.05100
#
#                                   50%        75%      max
# Overall rank                  78.5000  117.25000  156.000
# Score                          5.3780    6.16850    7.632
# GDP per capita                 0.9495    1.19775    2.096
# Social support                 1.2550    1.46300    1.644
# Healthy life expectancy        0.6440    0.77725    1.030
# Freedom to make life choices   0.4870    0.57850    0.724
# Generosity                     0.1740    0.23900    0.598
# Perceptions of corruption      0.0820    0.13700    0.457

# %%
whr_2019.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
whr_2019.describe().T
# Out:
#                               count       mean        std    min       25%  \
# Overall rank                  156.0  78.500000  45.177428  1.000  39.75000
# Score                         156.0   5.407096   1.113120  2.853   4.54450
# GDP per capita                156.0   0.905147   0.398389  0.000   0.60275
# Social support                156.0   1.208814   0.299191  0.000   1.05575
# Healthy life expectancy       156.0   0.725244   0.242124  0.000   0.54775
# Freedom to make life choices  156.0   0.392571   0.143289  0.000   0.30800
# Generosity                    156.0   0.184846   0.095254  0.000   0.10875
# Perceptions of corruption     156.0   0.110603   0.094538  0.000   0.04700
#
#                                   50%        75%      max
# Overall rank                  78.5000  117.25000  156.000
# Score                          5.3795    6.18450    7.769
# GDP per capita                 0.9600    1.23250    1.684
# Social support                 1.2715    1.45250    1.624
# Healthy life expectancy        0.7890    0.88175    1.141
# Freedom to make life choices   0.4170    0.50725    0.631
# Generosity                     0.1775    0.24825    0.566
# Perceptions of corruption      0.0855    0.14125    0.453

# %%
# whr_2018["GDP per capita"].hist()
plt.hist(whr_2018["GDP per capita"])

plt.xlabel("GDP contribution")
plt.ylabel("count")
plt.show()

# %%
whr_2018["GDP per capita"].mean()
# Out:
# 0.8914487179487179

# %%
plt.hist(whr_2018["GDP per capita"], bins = 50)

plt.xlabel("GDP contribution")
plt.ylabel("count")
plt.show()

# %%
whr_2018[(whr_2018["GDP per capita"] > 1.5) & (whr_2018["GDP per capita"] < 2.0)].sort_values("GDP per capita")
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 33            34         Singapore  6.343           1.529           1.451
# 16            17        Luxembourg  6.910           1.576           1.520
# 31            32             Qatar  6.374           1.649           1.303
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 33                    1.008                         0.631       0.261
# 16                    0.896                         0.632       0.196
# 31                    0.748                         0.654       0.256
#
#     Perceptions of corruption
# 33                      0.457
# 16                      0.321
# 31                      0.171

# %%
plt.hist(whr_2018.nsmallest(10, "GDP per capita")["GDP per capita"])
plt.show()

# %%
plt.hist(whr_2018["GDP per capita"], bins = 15, label = "2018", alpha = 0.7)
plt.hist(whr_2019["GDP per capita"], bins = 15, label = "2019", alpha = 0.7)

plt.legend()
plt.xlabel("GDP contribution")
plt.ylabel("count")
plt.show()

# %%
plt.hist(whr_2018["Score"], bins = 15, label = "2018", alpha = 0.7)
plt.hist(whr_2019["Score"], bins = 15, label = "2019", alpha = 0.7)

plt.legend()
plt.xlabel("Score")
plt.ylabel("count")
plt.show()

# %%
plt.boxplot(whr_2018["Score"])
plt.show()

# %%
plt.boxplot([whr_2018["Score"], whr_2019["Score"]])
plt.xticks([1, 2], ["2018", "2019"])
plt.show()

# %%
whr_2018.merge(whr_2019, on = "Country or region")
# Out:
#      Overall rank_x         Country or region  Score_x  GDP per capita_x  \
# 0                 1                   Finland    7.632             1.305
# 1                 2                    Norway    7.594             1.456
# 2                 3                   Denmark    7.555             1.351
# 3                 4                   Iceland    7.495             1.343
# 4                 5               Switzerland    7.487             1.420
# ..              ...                       ...      ...               ...
# 147             152                     Yemen    3.355             0.442
# 148             153                  Tanzania    3.303             0.455
# 149             154               South Sudan    3.254             0.337
# 150             155  Central African Republic    3.083             0.024
# 151             156                   Burundi    2.905             0.091
#
#      Social support_x  Healthy life expectancy_x  \
# 0               1.592                      0.874
# 1               1.582                      0.861
# 2               1.590                      0.868
# 3               1.644                      0.914
# 4               1.549                      0.927
# ..                ...                        ...
# 147             1.073                      0.343
# 148             0.991                      0.381
# 149             0.608                      0.177
# 150             0.000                      0.010
# 151             0.627                      0.145
#
#      Freedom to make life choices_x  Generosity_x  \
# 0                             0.681         0.202
# 1                             0.686         0.286
# 2                             0.683         0.284
# 3                             0.677         0.353
# 4                             0.660         0.256
# ..                              ...           ...
# 147                           0.244         0.083
# 148                           0.481         0.270
# 149                           0.112         0.224
# 150                           0.305         0.218
# 151                           0.065         0.149
#
#      Perceptions of corruption_x  Overall rank_y  Score_y  GDP per capita_y  \
# 0                          0.393               1    7.769             1.340
# 1                          0.340               3    7.554             1.488
# 2                          0.408               2    7.600             1.383
# 3                          0.138               4    7.494             1.380
# 4                          0.357               6    7.480             1.452
# ..                           ...             ...      ...               ...
# 147                        0.064             151    3.380             0.287
# 148                        0.097             153    3.231             0.476
# 149                        0.106             156    2.853             0.306
# 150                        0.038             155    3.083             0.026
# 151                        0.076             145    3.775             0.046
#
#      Social support_y  Healthy life expectancy_y  \
# 0               1.587                      0.986
# 1               1.582                      1.028
# 2               1.573                      0.996
# 3               1.624                      1.026
# 4               1.526                      1.052
# ..                ...                        ...
# 147             1.163                      0.463
# 148             0.885                      0.499
# 149             0.575                      0.295
# 150             0.000                      0.105
# 151             0.447                      0.380
#
#      Freedom to make life choices_y  Generosity_y  Perceptions of corruption_y
# 0                             0.596         0.153                        0.393
# 1                             0.603         0.271                        0.341
# 2                             0.592         0.252                        0.410
# 3                             0.591         0.354                        0.118
# 4                             0.572         0.263                        0.343
# ..                              ...           ...                          ...
# 147                           0.143         0.108                        0.077
# 148                           0.417         0.276                        0.147
# 149                           0.010         0.202                        0.091
# 150                           0.225         0.235                        0.035
# 151                           0.220         0.176                        0.180
#
# [152 rows x 17 columns]

# %%
whr_merged = whr_2018.merge(whr_2019, left_on = "Country or region", right_on = "Country or region", suffixes = ["_2018", "_2019"])

# %%
whr_merged[["Country or region", "Score_2018", "Score_2019"]]
# Out:
#             Country or region  Score_2018  Score_2019
# 0                     Finland       7.632       7.769
# 1                      Norway       7.594       7.554
# 2                     Denmark       7.555       7.600
# 3                     Iceland       7.495       7.494
# 4                 Switzerland       7.487       7.480
# ..                        ...         ...         ...
# 147                     Yemen       3.355       3.380
# 148                  Tanzania       3.303       3.231
# 149               South Sudan       3.254       2.853
# 150  Central African Republic       3.083       3.083
# 151                   Burundi       2.905       3.775
#
# [152 rows x 3 columns]

# %%
scores = whr_merged[["Country or region", "Score_2018", "Score_2019"]]

# %%
scores.nlargest(20, "Score_2018")
# Out:
#        Country or region  Score_2018  Score_2019
# 0                Finland       7.632       7.769
# 1                 Norway       7.594       7.554
# 2                Denmark       7.555       7.600
# 3                Iceland       7.495       7.494
# 4            Switzerland       7.487       7.480
# 5            Netherlands       7.441       7.488
# 6                 Canada       7.328       7.278
# 7            New Zealand       7.324       7.307
# 8                 Sweden       7.314       7.343
# 9              Australia       7.272       7.228
# 10        United Kingdom       7.190       7.054
# 11               Austria       7.139       7.246
# 12            Costa Rica       7.072       7.167
# 13               Ireland       6.977       7.021
# 14               Germany       6.965       6.985
# 15               Belgium       6.927       6.923
# 16            Luxembourg       6.910       7.090
# 17         United States       6.886       6.892
# 18                Israel       6.814       7.139
# 19  United Arab Emirates       6.774       6.825

# %%
plt.barh(scores.nlargest(20, "Score_2018")["Country or region"], scores.nlargest(20, "Score_2018")["Score_2018"])
plt.gca().invert_yaxis()
plt.xlim(0, 8)
plt.show()

# %%
plt.barh(scores.nsmallest(20, "Score_2018")["Country or region"], scores.nsmallest(20, "Score_2018")["Score_2018"])
plt.xlim(0, 8)
plt.show()

# %%
plt.figure(figsize=(20,20))

plt.barh(scores.nsmallest(20, "Score_2018")["Country or region"], scores.nsmallest(20, "Score_2018")["Score_2018"])
plt.xlim(0, 8)
plt.show()

# %%
whr_merged = whr_merged.merge(whr_2017.rename(columns=lambda col: col + "_2017"), left_on = "Country or region", right_on= "Country_2017", suffixes=["", "_2017"])

# %%
whr_merged = whr_merged.rename(columns = {"Happiness.Score_2017": "Score_2017"})

# %%
scores = whr_merged[["Country or region", "Score_2017", "Score_2018", "Score_2019"]]

# %%
bg_scores = scores[scores["Country or region"] == "Bulgaria"].T.drop("Country or region").values.ravel()
ro_scores = scores[scores["Country or region"] == "Romania"].T.drop("Country or region").values.ravel()

# %%
years = list(range(2017, 2020))

# %%
plt.scatter(years, bg_scores)
plt.xticks(years)
plt.show()

# %%
plt.plot(years, bg_scores, linewidth = 2, linestyle = "dashed", label = "BG")
plt.scatter(years, bg_scores, marker="s", s = 50)

plt.plot(years, ro_scores, linewidth = 2, linestyle = "dashed", label = "RO")
plt.scatter(years, ro_scores, marker="s", s = 50)

plt.title("Bulgaria: Happiness Score")
plt.xlabel("Year")
plt.ylabel("Score")
plt.xticks(years)
plt.legend(loc = "lower right")
plt.show()

# plt.savefig("figure.jpeg") # svg, pdf, eps

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']
